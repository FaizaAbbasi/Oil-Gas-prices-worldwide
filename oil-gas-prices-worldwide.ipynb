# %% [markdown]
# # **Petrol & Gas (Oil) Consumption and Prices Worldwide**
# * Faiza Abbasi
# * faizaabbasi988@gmail.com

# %% [markdown]
# ### **Table of Contents**
# 1. **Introduction**
#     <br>1.1. Dataset
# 2. **Problem Statement**
# 3. **Preparing Data**
# 4. **Exploratory Data Analysis (EDA)**
#     * Data Shape
#     * Data Structure
#     * Type Conversion
#     * Number of Unique values
#     * Unique values
#     * NaN values in Dataset
#     * Mean
#     * Descriptive Statistics
#     * Horizontal and Vertical shift of data
# 5. **Solution for Problem Statements**

# %% [markdown]
# ## **1. Introduction**
# Petrol & Gas (Oil) production has increased rapidly over the years and in order to keep track of the production<br>
# and consumption, Data Analytics is implemented. With Data Analytics we can not only bring insights of<br>
# the Upstream and Downstream of Oil Production but can also forecast the Consumption based on the<br>
# history.
#
# **Note:** Instead of using words like "Petrol, Fuel and Gas" we'd call it "Oil" for the ease.

# %% [markdown]
# ![Oil_stream.png](attachment:ad5da532-7bc7-49db-be3c-e7f3f67cffbb.png)

# %% [markdown]
# Today we will be looking at Oil & Gas Consumption and Prices dataset.<br>
# We will perform EDA-Analysis of data to give insights about different countries.<br>
#
# ### **1.1. Dataset: Petrol/Gas Prices Worldwide**
# **Link**: https://www.kaggle.com/datasets/zusmani/petrolgas-prices-worldwide
#
# **The Features:**
# 1. Serial
# 2. Country
# 3. Daily Oil Consumption (Barrels)
# 4. World Share
# 5. **Yearly Gallons Per Capita:** Gallons of Oil a single person Consumes in a Year
# 6. Price Per Gallon (USD)
# 7. Price Per Liter (USD)
# 8. Price Per Liter (PKR)
# 9. **GDP Per Capita ( USD ):** Economic activity of a single person (Dollars)
# 10. **Gallons GDP Per Capita Can Buy:** Gallons of Oil a single person could Buy in a Year
# 11. xTimes Yearly Gallons Per Capita Buy

# %% [markdown]
# ## **2. Problem Statement**
#
# 1. **Forecast Oil & Gas Consumption along with the prices**<br>
# 2. **Visualize Top 10 countries with highest "Daily Oil Consumption".**
# 3. **Visualize Top 10 countries with highest "Share of Oil".**
# 4. **Visualize Top 10 countries with highest "GDP Per Capita"**
# 5. **Visualize 10 countries that consumes highest Oil per person**
# 6. **Which 10 countries can "Buy the Oil" the most?**
# 7. **Relation between price per liter (USD) and GDP Per Capita?**
# 8. **Correlation of all features among eachother**

# %% [markdown]
# ## **3. Preparing Data**
# ### **3.1 Importing essential libraries**

# %%
# For Numeric Computation
import numpy as np

# For Data Analysis
import pandas as pd

# For Data Visualization
import matplotlib.pyplot as plt
import seaborn as sns

# For Interactive Visualization
import plotly.express as px
import plotly.graph_objects as go

# %% [markdown]
# ### **3.2 Importing Dataset**

# %%
# Dataset through Pandas
# Reason for using ISO-8859-1:
#   The dataset exceeds utf-8 (0-127) encoding. It requires a larger-width encodig such as latin-1 or ISO-8859-1 (0-255)
df = pd.read_csv('../input/petrolgas-prices-worldwide/Petrol Dataset June 23 2022 -- Version 2.csv',encoding='ISO-8859-1')

# View a sample of Dataset
df.head()
# Out:
#    S#        Country Daily Oil Consumption (Barrels) World Share  \
# 0   1  United States                      19,687,287         20%
# 1   2          China                      12,791,553         13%
# 2   3          India                       4,443,000          5%
# 3   4          Japan                       4,012,877          4%
# 4   5         Russia                       3,631,287          4%
#
#    Yearly Gallons Per Capita  Price Per Gallon (USD)  Price Per Liter (USD)  \
# 0                      934.3                    5.19                   1.37
# 1                      138.7                    5.42                   1.43
# 2                       51.4                    5.05                   1.33
# 3                      481.5                    4.69                   1.24
# 4                      383.2                    3.41                   0.90
#
#    Price Per Liter (PKR) GDP Per Capita ( USD )  \
# 0                 289.97                 63,414
# 1                 302.87                 10,435
# 2                 281.93                  1,901
# 3                 262.05                 40,193
# 4                 190.56                 10,127
#
#   Gallons GDP Per Capita Can Buy  xTimes Yearly Gallons Per Capita Buy
# 0                         12,218                                    13
# 1                          1,925                                    14
# 2                            376                                     7
# 3                          8,570                                    18
# 4                          2,970                                     8

# %% [markdown]
# ## **4. Exploratory Data Analysis (EDA)**

# %% [markdown]
# ### Data Shape

# %%
# Step 1: Data shape
print(df.shape)
rows, columns = df.shape
print(f"Num of Rows: {rows} ") # instances
print(f"Num of Columns: {columns} ") # series
print(f"The size (rows x columns) is: {df.size}") # size
print(f"The Dimensions are: {df.ndim}") # dimensions
# Out:
# (181, 11)
# Num of Rows: 181
# Num of Columns: 11
# The size (rows x columns) is: 1991
# The Dimensions are: 2

# %% [markdown]
# ### Data Structure

# %%
# Step 2: Data Structure
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181 entries, 0 to 180
# Data columns (total 11 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   S#                                    181 non-null    int64
#  1   Country                               181 non-null    object
#  2   Daily Oil Consumption (Barrels)       181 non-null    object
#  3   World Share                           181 non-null    object
#  4   Yearly Gallons Per Capita             181 non-null    float64
#  5   Price Per Gallon (USD)                181 non-null    float64
#  6   Price Per Liter (USD)                 181 non-null    float64
#  7   Price Per Liter (PKR)                 181 non-null    float64
#  8   GDP Per Capita ( USD )                181 non-null    object
#  9   Gallons GDP Per Capita Can Buy        181 non-null    object
#  10  xTimes Yearly Gallons Per Capita Buy  181 non-null    int64
# dtypes: float64(4), int64(2), object(5)
# memory usage: 15.7+ KB

# %% [markdown]
# ### Type Conversion

# %%
# Since we've a lot of features in "Object/String" datatype. Let's convert them into Float

# Creating a dictionary of all special characters in our dataset
char = {'%': '',
        ',': '',}

# Looping through all the features one by one
for feature in df.columns:
# Creating a condition to only target "Object" datatype and ignore the rest including the "Country" column
    if df[feature].dtype == "object" and feature != "Country":
# Creating a loop for the dictionary
        for key, value in char.items():
# If the special characters are in the columns then they'd get replaced by '' empty space
            df[feature] = df[feature].str.replace(key, value)
# After removing special character we're converting the features from "Object" to "Float" datatype
        df[feature] = df[feature].astype("float64")

# %% [markdown]
# ### Checking Type Coversion
# We've successfully converted the required features into float datatype

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181 entries, 0 to 180
# Data columns (total 11 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   S#                                    181 non-null    int64
#  1   Country                               181 non-null    object
#  2   Daily Oil Consumption (Barrels)       181 non-null    float64
#  3   World Share                           181 non-null    float64
#  4   Yearly Gallons Per Capita             181 non-null    float64
#  5   Price Per Gallon (USD)                181 non-null    float64
#  6   Price Per Liter (USD)                 181 non-null    float64
#  7   Price Per Liter (PKR)                 181 non-null    float64
#  8   GDP Per Capita ( USD )                181 non-null    float64
#  9   Gallons GDP Per Capita Can Buy        181 non-null    float64
#  10  xTimes Yearly Gallons Per Capita Buy  181 non-null    int64
# dtypes: float64(8), int64(2), object(1)
# memory usage: 15.7+ KB

# %% [markdown]
# ### Num of Unique values in Dataset

# %%
df.nunique()
# Out:
# S#                                      181
# Country                                 181
# Daily Oil Consumption (Barrels)         156
# World Share                               8
# Yearly Gallons Per Capita               180
# Price Per Gallon (USD)                  156
# Price Per Liter (USD)                   118
# Price Per Liter (PKR)                   165
# GDP Per Capita ( USD )                  178
# Gallons GDP Per Capita Can Buy          178
# xTimes Yearly Gallons Per Capita Buy     34
# dtype: int64

# %% [markdown]
# ### List of the Countries (Unique values)

# %%
df["Country"].unique()
# Out:
# array(['United States', 'China', 'India', 'Japan', 'Russia',
#        'Saudi Arabia', 'Brazil', 'South Korea', 'Canada', 'Germany',
#        'Mexico', 'Iran', 'France', 'Indonesia', 'United Kingdom',
#        'Singapore', 'Italy', 'Spain', 'Thailand', 'Australia', 'Taiwan',
#        'Turkey', 'Netherlands', 'Egypt', 'United Arab Emirates', 'Iraq',
#        'Malaysia', 'Argentina', 'Belgium', 'South Africa', 'Venezuela',
#        'Poland', 'Pakistan', 'Vietnam', 'Nigeria', 'Colombia', 'Algeria',
#        'Kuwait', 'Philippines', 'Chile', 'Hong Kong', 'Kazakhstan',
#        'Austria', 'Sweden', 'Peru', 'Ukraine', 'Ecuador', 'Greece',
#        'Morocco', 'Libya', 'Switzerland', 'Qatar', 'Ireland', 'Denmark',
#        'Israel', 'Romania', 'Czech Republic (Czechia)', 'Turkmenistan',
#        'Norway', 'New Zealand', 'Cuba', 'Oman', 'Hungary', 'Finland',
#        'Portugal', 'Panama', 'Lebanon', 'Bangladesh', 'Angola', 'Syria',
#        'Puerto Rico', 'Azerbaijan', 'Belarus', 'Guatemala', 'Kenya',
#        'Tunisia', 'Sri Lanka', 'Myanmar', 'Bulgaria',
#        'Dominican Republic', 'Jordan', 'Sudan', 'Bolivia', 'Ghana',
#        'Ethiopia', 'Slovakia', 'Serbia', 'Tanzania', 'Croatia', 'Bahrain',
#        'Yemen', 'Costa Rica', 'Luxembourg', 'Uruguay', 'Lithuania',
#        'Trinidad and Tobago', 'Honduras', 'Jamaica', 'Uzbekistan',
#        "Côte d'Ivoire", 'Slovenia', 'Paraguay', 'El Salvador', 'Cambodia',
#        'Cyprus', 'Senegal', 'Malta', 'Cameroon', 'Afghanistan', 'Nepal',
#        'Latvia', 'Benin', 'Papua New Guinea', 'Bosnia and Herzegovina',
#        'Mozambique', 'Nicaragua', 'Kyrgyzstan', 'Uganda', 'Estonia',
#        'Zimbabwe', 'Georgia', 'State of Palestine', 'Namibia', 'Albania',
#        'Mauritius', 'Brunei ', 'Macao', 'DR Congo', 'Haiti', 'Gabon',
#        'Madagascar', 'Botswana', 'Burkina Faso', 'Moldova', 'Mali',
#        'Congo', 'Togo', 'Guinea', 'Zambia', 'Laos', 'Mongolia', 'Iceland',
#        'North Macedonia', 'Bahamas', 'Tajikistan', 'New Caledonia',
#        'Fiji', 'North Korea', 'Armenia', 'Malawi', 'South Sudan',
#        'Rwanda', 'Somalia', 'Montenegro', 'Sierra Leone', 'Guyana',
#        'Maldives', 'Liberia', 'Suriname', 'Aruba', 'Lesotho', 'Barbados',
#        'Cabo Verde', 'Seychelles', 'Burundi', 'British Virgin Islands',
#        'Cayman Islands', 'Bhutan', 'Comoros', 'Vanuatu', 'Saint Helena',
#        'Kiribati', 'Grenada', 'Gambia', 'Central African Republic',
#        'Dominica', 'Belize', 'Niue', 'Saint Pierre & Miquelon',
#        'Montserrat', 'Tonga'], dtype=object)

# %% [markdown]
# ### NaN values in Dataset

# %%
df.isnull().sum()
# Out:
# S#                                      0
# Country                                 0
# Daily Oil Consumption (Barrels)         0
# World Share                             0
# Yearly Gallons Per Capita               0
# Price Per Gallon (USD)                  0
# Price Per Liter (USD)                   0
# Price Per Liter (PKR)                   0
# GDP Per Capita ( USD )                  0
# Gallons GDP Per Capita Can Buy          0
# xTimes Yearly Gallons Per Capita Buy    0
# dtype: int64

# %% [markdown]
# ### Mean of the Dataset

# %%
df.mean(numeric_only=True)
# Out:
# S#                                          91.000000
# Daily Oil Consumption (Barrels)         533573.049724
# World Share                                  0.497238
# Yearly Gallons Per Capita                  332.006630
# Price Per Gallon (USD)                       5.695691
# Price Per Liter (USD)                        1.505138
# Price Per Liter (PKR)                      318.219227
# GDP Per Capita ( USD )                   15259.790055
# Gallons GDP Per Capita Can Buy            4179.342541
# xTimes Yearly Gallons Per Capita Buy        14.204420
# dtype: float64

# %% [markdown]
# ### Descriptive Statistics

# %%
round(df.describe(),1)
# Out:
#           S#  Daily Oil Consumption (Barrels)  World Share  \
# count  181.0                            181.0        181.0
# mean    91.0                         533573.0          0.5
# std     52.4                        1858067.1          1.9
# min      1.0                             51.0          0.0
# 25%     46.0                          20036.0          0.0
# 50%     91.0                          61612.0          0.0
# 75%    136.0                         262352.0          0.0
# max    181.0                       19687287.0         20.0
#
#        Yearly Gallons Per Capita  Price Per Gallon (USD)  \
# count                      181.0                   181.0
# mean                       332.0                     5.7
# std                        436.6                     4.4
# min                          2.2                     0.1
# 25%                         53.9                     4.2
# 50%                        180.2                     5.3
# 75%                        424.6                     6.8
# max                       3679.5                    54.9
#
#        Price Per Liter (USD)  Price Per Liter (PKR)  GDP Per Capita ( USD )  \
# count                  181.0                  181.0                   181.0
# mean                     1.5                  318.2                 15259.8
# std                      1.2                  244.2                 20542.2
# min                      0.0                    4.6                   274.0
# 25%                      1.1                  232.0                  2033.0
# 50%                      1.4                  295.0                  6127.0
# 75%                      1.8                  377.7                 20234.0
# max                     14.5                 3066.8                115874.0
#
#        Gallons GDP Per Capita Can Buy  xTimes Yearly Gallons Per Capita Buy
# count                           181.0                                 181.0
# mean                           4179.3                                  14.2
# std                           15436.4                                  48.6
# min                              24.0                                   1.0
# 25%                             473.0                                   6.0
# 50%                            1410.0                                   9.0
# 75%                            4103.0                                  12.0
# max                          200700.0                                 654.0

# %% [markdown]
# * **Min Oil Consumed (Barrels) per day: 51 Barrels**
# * **Max Oil Consumed (Barrels) per day: 19.6 Million Barrels**
# * **Average Oil Consumed (Barrels) per day: 0.5 Million Barrels**
# * **Min Oil Price (PKR) per liter: 4.6 PKR**
# * **Max Oil Price (PKR) per liter: 3066.8 PKR**
# * **Average Oil Price (PKR) per liter: 318.2 PKR**

# %% [markdown]
# ### Horizontal and Vertical shift of data
# **Most of the countries that've close to zero oil consumption (not actual zero) would cause a huge Kurtosis around Zero.<br> Meanwhile countries like United States, China etc
# would appear as a rarity when plotted.**

# %%
# Measure its skewness and kurtosis
skew, kurtosis = df["Daily Oil Consumption (Barrels)"].agg(["skew", "kurtosis"]).transpose()
print(f"Skew is: {skew:.3f} , Kurtosis is: {kurtosis:.3f}")
sns.histplot(df["Daily Oil Consumption (Barrels)"])
# Out:
# Skew is: 7.930 , Kurtosis is: 72.994
# <AxesSubplot:xlabel='Daily Oil Consumption (Barrels)', ylabel='Count'>

# %% [markdown]
# ## **5. Solution for Problem Statements**

# %% [markdown]
# ### **5.1 Forecast Oil & Gas Consumption along with the prices**
# **Data is limited and is not based on previous history of all the countries so we can't forecast anything.**

# %% [markdown]
# ### **5.2 Visualize Top 10 countries with highest "Daily Oil Consumption"**

# %%
fig=px.pie(df.head(10),values='Daily Oil Consumption (Barrels)',names='Country',hole=0.5)
fig.update_layout(title='Daily Oil Consumption (Barrels) - Top 10 Countries',font_size=15,title_x=0.45,annotations=[dict(text='Countries',font_size=18, showarrow=False)])
fig.update_traces(textfont_size=15,textinfo='percent')
fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="6981f85d-1ea8-48c4-9400-d7075818679c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6981f85d-1ea8-48c4-9400-d7075818679c")) {                    Plotly.newPlot(                        "6981f85d-1ea8-48c4-9400-d7075818679c",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hole":0.5,"hovertemplate":"Country=%{label}<br>Daily Oil Consumption (Barrels)=%{value}<extra></extra>","labels":["United States","China","India","Japan","Russia","Saudi Arabia","Brazil","South Korea","Canada","Germany"],"legendgroup":"","name":"","showlegend":true,"values":[19687287.0,12791553.0,4443000.0,4012877.0,3631287.0,3302000.0,2984000.0,2605440.0,2486301.0,2383393.0],"type":"pie","textfont":{"size":15},"textinfo":"percent"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo ...

# %% [markdown]
# ### **5.3 Visualize Top 10 countries with highest "Share of Oil"**

# %%
top_share = df.nlargest(10, 'World Share')

# Create a stacked bar with more customization
fig = px.bar(top_share, x='Country', y='World Share', color='Country', title='Top 10 countries with highest "Share of Oil "',

      labels={'World Share': 'World Shares (%) ', 'Country': 'Country '})
fig.update_layout(font_size=15, title_x=0.45, xaxis_tickangle=-45)
# Out:
# <div>                            <div id="37afe6d6-37f2-4490-85cd-21d97f9fad9a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("37afe6d6-37f2-4490-85cd-21d97f9fad9a")) {                    Plotly.newPlot(                        "37afe6d6-37f2-4490-85cd-21d97f9fad9a",                        [{"alignmentgroup":"True","hovertemplate":"Country =%{x}<br>World Shares (%) =%{y}<extra></extra>","legendgroup":"United States","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"United States","offsetgroup":"United States","orientation":"v","showlegend":true,"textposition":"auto","x":["United States"],"xaxis":"x","y":[20.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country =%{x}<br>World Shares (%) =%{y}<extra></extra>","legendgroup":"China","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"China","offsetgroup":"China","orientation":"v","showlegend":true,"textposition":"auto","x":["China"],"xaxis":"x","y":[13.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country =%{x}<br>World Shares (%) =%{y}<extra></extra>","legendgroup":"India","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"India","offsetgroup":"India","orientation":"v","showlegend":true,"textposition":"auto","x":["India"],"xaxis":"x","y":[5.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country =%{x}<br>World Shares (%) =%{y}<extra></extra>","legendgroup":"Japan","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Japan","offsetgroup":"Japan","orientation":"v","showlegend":true,"textposition":"auto","x":["Japan"],"xaxis":"x","y":[4.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country =%{x}<br>World Shares (%) =%{y}<extra></extra>","legendgroup":"Russia","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Russia","offsetgroup":"Russia","orientation":"v","showlegend":true,"textposition":"auto","x":["Russia"],"xaxis":"x","y":[4.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country =%{x}<br>World Shares (%) =%{y}<extra></extra>","legendgroup":"Saudi Arabia","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Saudi Arabia","offsetgroup":"Saudi Arabia","orientation":"v","showlegend":true,"textposition":"auto","x":["Saudi Arabia"],"xaxis":"x","y":[3.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country =%{x}<br>World Shares (%) =%{y}<extra></extra>","legendgroup":"Brazil","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Brazil","offsetgroup":"Brazil","orientation":"v","showlegend":true,"textposition":"auto","x":["Brazil"],"xaxis":"x","y":[3.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country =%{x}<br>World Shares (%) =%{y}<extra></extra>","legendgroup":"South Korea","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"South Korea","offsetgroup":"South Korea","orientation":"v","showlegend":true,"textposition":"auto","x":["South Korea"],"xaxis":"x","y":[3.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country =%{x}<br>World Shares (%) =%{y}<extra></extra>","legendgroup":"Canada","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"Canada","offsetgroup":"Canada","orientation":"v","showlegend":true,"textposition":"auto","x":["Canada"],"xaxis":"x","y":[3.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country =%{x}<br>World Shares (%) =%{y}<extra></extra>","legendgroup":"Germany","marker":{"color":"#FECB52","pattern":{"shape":""}},"name":"Germany","offsetgroup":"Germany","orientation":"v","showlegend":true,"textposition":"auto","x":["Germany"],"xaxis":"x","y":[3.0],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"typ ...

# %% [markdown]
# ### **5.4 Visualize Top 10 countries with highest "GDP Per Capita (USD)"**

# %%
top_share = df.nlargest(10, 'GDP Per Capita ( USD )')

# fig = px.violin(top_share, x="Country", y="GDP Per Capita ( USD )",  color="Country", box=False, points='all')
# fig.show()

fig = px.scatter(top_share, x="Country", y="GDP Per Capita ( USD )", size="GDP Per Capita ( USD )", color="Country", title='Top 10 countries with highest "GDP Per Capita"',
                 hover_name="Country", log_x=False, size_max=100)
fig.update_layout(font_size=15, title_x=0.45, xaxis_tickangle=-45)
fig.show()
# Out:
# <div>                            <div id="f5da71cd-5e84-4120-8894-196b213e0aa8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f5da71cd-5e84-4120-8894-196b213e0aa8")) {                    Plotly.newPlot(                        "f5da71cd-5e84-4120-8894-196b213e0aa8",                        [{"hovertemplate":"<b>%{hovertext}</b><br><br>Country=%{x}<br>GDP Per Capita ( USD )=%{marker.size}<extra></extra>","hovertext":["Luxembourg"],"legendgroup":"Luxembourg","marker":{"color":"#636efa","size":[115874.0],"sizemode":"area","sizeref":11.5874,"symbol":"circle"},"mode":"markers","name":"Luxembourg","orientation":"v","showlegend":true,"x":["Luxembourg"],"xaxis":"x","y":[115874.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"<b>%{hovertext}</b><br><br>Country=%{x}<br>GDP Per Capita ( USD )=%{marker.size}<extra></extra>","hovertext":["Switzerland"],"legendgroup":"Switzerland","marker":{"color":"#EF553B","size":[87097.0],"sizemode":"area","sizeref":11.5874,"symbol":"circle"},"mode":"markers","name":"Switzerland","orientation":"v","showlegend":true,"x":["Switzerland"],"xaxis":"x","y":[87097.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"<b>%{hovertext}</b><br><br>Country=%{x}<br>GDP Per Capita ( USD )=%{marker.size}<extra></extra>","hovertext":["Macao"],"legendgroup":"Macao","marker":{"color":"#00cc96","size":[86117.0],"sizemode":"area","sizeref":11.5874,"symbol":"circle"},"mode":"markers","name":"Macao","orientation":"v","showlegend":true,"x":["Macao"],"xaxis":"x","y":[86117.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"<b>%{hovertext}</b><br><br>Country=%{x}<br>GDP Per Capita ( USD )=%{marker.size}<extra></extra>","hovertext":["Ireland"],"legendgroup":"Ireland","marker":{"color":"#ab63fa","size":[85268.0],"sizemode":"area","sizeref":11.5874,"symbol":"circle"},"mode":"markers","name":"Ireland","orientation":"v","showlegend":true,"x":["Ireland"],"xaxis":"x","y":[85268.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"<b>%{hovertext}</b><br><br>Country=%{x}<br>GDP Per Capita ( USD )=%{marker.size}<extra></extra>","hovertext":["Cayman Islands"],"legendgroup":"Cayman Islands","marker":{"color":"#FFA15A","size":[85083.0],"sizemode":"area","sizeref":11.5874,"symbol":"circle"},"mode":"markers","name":"Cayman Islands","orientation":"v","showlegend":true,"x":["Cayman Islands"],"xaxis":"x","y":[85083.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"<b>%{hovertext}</b><br><br>Country=%{x}<br>GDP Per Capita ( USD )=%{marker.size}<extra></extra>","hovertext":["Norway"],"legendgroup":"Norway","marker":{"color":"#19d3f3","size":[67390.0],"sizemode":"area","sizeref":11.5874,"symbol":"circle"},"mode":"markers","name":"Norway","orientation":"v","showlegend":true,"x":["Norway"],"xaxis":"x","y":[67390.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"<b>%{hovertext}</b><br><br>Country=%{x}<br>GDP Per Capita ( USD )=%{marker.size}<extra></extra>","hovertext":["United States"],"legendgroup":"United States","marker":{"color":"#FF6692","size":[63414.0],"sizemode":"area","sizeref":11.5874,"symbol":"circle"},"mode":"markers","name":"United States","orientation":"v","showlegend":true,"x":["United States"],"xaxis":"x","y":[63414.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"<b>%{hovertext}</b><br><br>Country=%{x}<br>GDP Per Capita ( USD )=%{marker.size}<extra></extra>","hovertext":["Denmark"],"legendgroup":"Denmark","marker":{"color":"#B6E880","size":[61063.0],"sizemode":"area","sizeref":11.5874,"symbol":"circle"},"mode":"markers","name":"Denmark","orientation":"v","showlegend":true,"x":["Denmark"],"xaxis":"x","y":[61063.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"<b>%{hovertext}</b><br><br>Country=%{x}<br>GDP Per Capita ( USD )=%{marker.size}<extra></extra>","hovertext":["Singapore"],"legendgroup":"Sin ...

# %% [markdown]
# ### **5.5 Visualize 10 countries that consumes highest Oil per person**

# %%
df["Oil usage per person"] = df["Daily Oil Consumption (Barrels)"]/df["GDP Per Capita ( USD )"]

oil_share = df.nlargest(10, "Oil usage per person")
fig = px.bar(oil_share, x='Country', y='Oil usage per person',
             hover_data=['Country', 'GDP Per Capita ( USD )'], color='Country', title='Top 10 countries that consume highest Oil per Person')
fig.update_layout(font_size=15, title_x=0.45, xaxis_tickangle=-45)
fig.show()
# Out:
# <div>                            <div id="e1bf5029-fc90-4a4e-be7a-b40da30c8331" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e1bf5029-fc90-4a4e-be7a-b40da30c8331")) {                    Plotly.newPlot(                        "e1bf5029-fc90-4a4e-be7a-b40da30c8331",                        [{"alignmentgroup":"True","customdata":[[1901.0]],"hovertemplate":"Country=%{x}<br>Oil usage per person=%{y}<br>GDP Per Capita ( USD )=%{customdata[0]}<extra></extra>","legendgroup":"India","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"India","offsetgroup":"India","orientation":"v","showlegend":true,"textposition":"auto","x":["India"],"xaxis":"x","y":[2337.190952130458],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[10435.0]],"hovertemplate":"Country=%{x}<br>Oil usage per person=%{y}<br>GDP Per Capita ( USD )=%{customdata[0]}<extra></extra>","legendgroup":"China","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"China","offsetgroup":"China","orientation":"v","showlegend":true,"textposition":"auto","x":["China"],"xaxis":"x","y":[1225.8316243411596],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[2423.0]],"hovertemplate":"Country=%{x}<br>Oil usage per person=%{y}<br>GDP Per Capita ( USD )=%{customdata[0]}<extra></extra>","legendgroup":"Iran","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Iran","offsetgroup":"Iran","orientation":"v","showlegend":true,"textposition":"auto","x":["Iran"],"xaxis":"x","y":[744.5311597193562],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[1194.0]],"hovertemplate":"Country=%{x}<br>Oil usage per person=%{y}<br>GDP Per Capita ( USD )=%{customdata[0]}<extra></extra>","legendgroup":"Pakistan","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Pakistan","offsetgroup":"Pakistan","orientation":"v","showlegend":true,"textposition":"auto","x":["Pakistan"],"xaxis":"x","y":[465.66164154103853],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[6797.0]],"hovertemplate":"Country=%{x}<br>Oil usage per person=%{y}<br>GDP Per Capita ( USD )=%{customdata[0]}<extra></extra>","legendgroup":"Brazil","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Brazil","offsetgroup":"Brazil","orientation":"v","showlegend":true,"textposition":"auto","x":["Brazil"],"xaxis":"x","y":[439.01721347653375],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[3870.0]],"hovertemplate":"Country=%{x}<br>Oil usage per person=%{y}<br>GDP Per Capita ( USD )=%{customdata[0]}<extra></extra>","legendgroup":"Indonesia","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Indonesia","offsetgroup":"Indonesia","orientation":"v","showlegend":true,"textposition":"auto","x":["Indonesia"],"xaxis":"x","y":[419.37984496124034],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[10127.0]],"hovertemplate":"Country=%{x}<br>Oil usage per person=%{y}<br>GDP Per Capita ( USD )=%{customdata[0]}<extra></extra>","legendgroup":"Russia","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Russia","offsetgroup":"Russia","orientation":"v","showlegend":true,"textposition":"auto","x":["Russia"],"xaxis":"x","y":[358.57480003949837],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[63414.0]],"hovertemplate":"Country=%{x}<br>Oil usage per person=%{y}<br>GDP Per Capita ( USD )=%{customdata[0]}<extra></extra>","legendgroup":"United States","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"United States","offsetgroup":"United States","orientation":"v","showlegend":true,"textposition":"auto","x":["United States"],"xaxis":"x","y":[310.4564764878418],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[3548.0]],"hovertemplate":"Country=%{x}<br>Oil usage per perso ...

# %% [markdown]
# ### **5.6 Which 10 countries can "Buy the Oil" the most?**

# %%
buy_share = df.nlargest(10, "Gallons GDP Per Capita Can Buy")

fig = px.bar(oil_share, x='Gallons GDP Per Capita Can Buy', y='Country',
             hover_data=['Country', 'Gallons GDP Per Capita Can Buy'], color='Country', title='Top 10 countries that can Buy the most Oil')
fig.update_layout(font_size=15, title_x=0.45, xaxis_tickangle=-45)
fig.show()
# Out:
# <div>                            <div id="ed281631-6718-4291-85ec-2327185e9b0f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ed281631-6718-4291-85ec-2327185e9b0f")) {                    Plotly.newPlot(                        "ed281631-6718-4291-85ec-2327185e9b0f",                        [{"alignmentgroup":"True","hovertemplate":"Country=%{y}<br>Gallons GDP Per Capita Can Buy=%{x}<extra></extra>","legendgroup":"India","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"India","offsetgroup":"India","orientation":"h","showlegend":true,"textposition":"auto","x":[376.0],"xaxis":"x","y":["India"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country=%{y}<br>Gallons GDP Per Capita Can Buy=%{x}<extra></extra>","legendgroup":"China","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"China","offsetgroup":"China","orientation":"h","showlegend":true,"textposition":"auto","x":[1925.0],"xaxis":"x","y":["China"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country=%{y}<br>Gallons GDP Per Capita Can Buy=%{x}<extra></extra>","legendgroup":"Iran","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Iran","offsetgroup":"Iran","orientation":"h","showlegend":true,"textposition":"auto","x":[12115.0],"xaxis":"x","y":["Iran"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country=%{y}<br>Gallons GDP Per Capita Can Buy=%{x}<extra></extra>","legendgroup":"Pakistan","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Pakistan","offsetgroup":"Pakistan","orientation":"h","showlegend":true,"textposition":"auto","x":[306.0],"xaxis":"x","y":["Pakistan"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country=%{y}<br>Gallons GDP Per Capita Can Buy=%{x}<extra></extra>","legendgroup":"Brazil","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Brazil","offsetgroup":"Brazil","orientation":"h","showlegend":true,"textposition":"auto","x":[1268.0],"xaxis":"x","y":["Brazil"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country=%{y}<br>Gallons GDP Per Capita Can Buy=%{x}<extra></extra>","legendgroup":"Indonesia","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Indonesia","offsetgroup":"Indonesia","orientation":"h","showlegend":true,"textposition":"auto","x":[864.0],"xaxis":"x","y":["Indonesia"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country=%{y}<br>Gallons GDP Per Capita Can Buy=%{x}<extra></extra>","legendgroup":"Russia","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Russia","offsetgroup":"Russia","orientation":"h","showlegend":true,"textposition":"auto","x":[2970.0],"xaxis":"x","y":["Russia"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country=%{y}<br>Gallons GDP Per Capita Can Buy=%{x}<extra></extra>","legendgroup":"United States","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"United States","offsetgroup":"United States","orientation":"h","showlegend":true,"textposition":"auto","x":[12218.0],"xaxis":"x","y":["United States"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country=%{y}<br>Gallons GDP Per Capita Can Buy=%{x}<extra></extra>","legendgroup":"Egypt","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"Egypt","offsetgroup":"Egypt","orientation":"h","showlegend":true,"textposition":"auto","x":[1801.0],"xaxis":"x","y":["Egypt"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country=%{y}<br>Gallons GDP Per Capita Can Buy=%{x}<extra></extra>","legendgroup":"Mexico","marker":{"color":"#FECB52","pattern":{"shape":""}},"name":"Mexico","offsetgroup":"Mexico","orientation":"h","showlegend":true,"textposition":"auto","x":[1910.0],"xaxis":"x","y" ...

# %% [markdown]
# ### **5.7 Relation between Price Per Liter (USD) and GDP Per Capita (USD)?**

# %%
fig = px.scatter(df, x="Price Per Liter (USD)", y="GDP Per Capita ( USD )", size = "GDP Per Capita ( USD )",
color = 'Country', title = 'Relation between Price Per Liter (USD) and GDP Per Capita (USD)', range_x=[0,6], log_y=False)
fig.update_layout(font_size=15, title_x=0.45, xaxis_tickangle=-45)
fig.show()
# Out:
# <div>                            <div id="19672839-9110-4711-981a-c07c145bc2b0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("19672839-9110-4711-981a-c07c145bc2b0")) {                    Plotly.newPlot(                        "19672839-9110-4711-981a-c07c145bc2b0",                        [{"hovertemplate":"Country=United States<br>Price Per Liter (USD)=%{x}<br>GDP Per Capita ( USD )=%{marker.size}<extra></extra>","legendgroup":"United States","marker":{"color":"#636efa","size":[63414.0],"sizemode":"area","sizeref":289.685,"symbol":"circle"},"mode":"markers","name":"United States","orientation":"v","showlegend":true,"x":[1.37],"xaxis":"x","y":[63414.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=China<br>Price Per Liter (USD)=%{x}<br>GDP Per Capita ( USD )=%{marker.size}<extra></extra>","legendgroup":"China","marker":{"color":"#EF553B","size":[10435.0],"sizemode":"area","sizeref":289.685,"symbol":"circle"},"mode":"markers","name":"China","orientation":"v","showlegend":true,"x":[1.43],"xaxis":"x","y":[10435.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=India<br>Price Per Liter (USD)=%{x}<br>GDP Per Capita ( USD )=%{marker.size}<extra></extra>","legendgroup":"India","marker":{"color":"#00cc96","size":[1901.0],"sizemode":"area","sizeref":289.685,"symbol":"circle"},"mode":"markers","name":"India","orientation":"v","showlegend":true,"x":[1.33],"xaxis":"x","y":[1901.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=Japan<br>Price Per Liter (USD)=%{x}<br>GDP Per Capita ( USD )=%{marker.size}<extra></extra>","legendgroup":"Japan","marker":{"color":"#ab63fa","size":[40193.0],"sizemode":"area","sizeref":289.685,"symbol":"circle"},"mode":"markers","name":"Japan","orientation":"v","showlegend":true,"x":[1.24],"xaxis":"x","y":[40193.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=Russia<br>Price Per Liter (USD)=%{x}<br>GDP Per Capita ( USD )=%{marker.size}<extra></extra>","legendgroup":"Russia","marker":{"color":"#FFA15A","size":[10127.0],"sizemode":"area","sizeref":289.685,"symbol":"circle"},"mode":"markers","name":"Russia","orientation":"v","showlegend":true,"x":[0.9],"xaxis":"x","y":[10127.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=Saudi Arabia<br>Price Per Liter (USD)=%{x}<br>GDP Per Capita ( USD )=%{marker.size}<extra></extra>","legendgroup":"Saudi Arabia","marker":{"color":"#19d3f3","size":[20110.0],"sizemode":"area","sizeref":289.685,"symbol":"circle"},"mode":"markers","name":"Saudi Arabia","orientation":"v","showlegend":true,"x":[0.62],"xaxis":"x","y":[20110.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=Brazil<br>Price Per Liter (USD)=%{x}<br>GDP Per Capita ( USD )=%{marker.size}<extra></extra>","legendgroup":"Brazil","marker":{"color":"#FF6692","size":[6797.0],"sizemode":"area","sizeref":289.685,"symbol":"circle"},"mode":"markers","name":"Brazil","orientation":"v","showlegend":true,"x":[1.42],"xaxis":"x","y":[6797.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=South Korea<br>Price Per Liter (USD)=%{x}<br>GDP Per Capita ( USD )=%{marker.size}<extra></extra>","legendgroup":"South Korea","marker":{"color":"#B6E880","size":[31632.0],"sizemode":"area","sizeref":289.685,"symbol":"circle"},"mode":"markers","name":"South Korea","orientation":"v","showlegend":true,"x":[1.61],"xaxis":"x","y":[31632.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=Canada<br>Price Per Liter (USD)=%{x}<br>GDP Per Capita ( USD )=%{marker.size}<extra></extra>","legendgroup":"Canada","marker":{"color":"#FF97FF","size":[43258.0],"sizemode":"area","sizeref":289.685,"symbol":"circle"},"mode":"markers","name":"Canada","orientation":"v","showlegend":true,"x":[1.79],"xaxis":"x","y":[43258.0],"yaxis":"y","type":"scatter"},{"hovertemplate":" ...

# %% [markdown]
# ### **5.8 Correlation of all features among eachother**

# %%
df.corr()
# Out:
#                                             S#  \
# S#                                    1.000000
# Daily Oil Consumption (Barrels)      -0.414058
# World Share                          -0.406384
# Yearly Gallons Per Capita            -0.188944
# Price Per Gallon (USD)                0.121811
# Price Per Liter (USD)                 0.121623
# Price Per Liter (PKR)                 0.121741
# GDP Per Capita ( USD )               -0.269779
# Gallons GDP Per Capita Can Buy       -0.160051
# xTimes Yearly Gallons Per Capita Buy -0.109388
# Oil usage per person                 -0.361556
#
#                                       Daily Oil Consumption (Barrels)  \
# S#                                                          -0.414058
# Daily Oil Consumption (Barrels)                              1.000000
# World Share                                                  0.995882
# Yearly Gallons Per Capita                                    0.149248
# Price Per Gallon (USD)                                      -0.029965
# Price Per Liter (USD)                                       -0.030106
# Price Per Liter (PKR)                                       -0.029938
# GDP Per Capita ( USD )                                       0.190066
# Gallons GDP Per Capita Can Buy                               0.051464
# xTimes Yearly Gallons Per Capita Buy                         0.007332
# Oil usage per person                                         0.487674
#
#                                       World Share  Yearly Gallons Per Capita  \
# S#                                      -0.406384                  -0.188944
# Daily Oil Consumption (Barrels)          0.995882                   0.149248
# World Share                              1.000000                   0.137480
# Yearly Gallons Per Capita                0.137480                   1.000000
# Price Per Gallon (USD)                  -0.030067                   0.057293
# Price Per Liter (USD)                   -0.030217                   0.057471
# Price Per Liter (PKR)                   -0.030040                   0.057368
# GDP Per Capita ( USD )                   0.181224                   0.622038
# Gallons GDP Per Capita Can Buy           0.064107                   0.150975
# xTimes Yearly Gallons Per Capita Buy     0.022268                  -0.025534
# Oil usage per person                     0.504923                  -0.081313
#
#                                       Price Per Gallon (USD)  \
# S#                                                  0.121811
# Daily Oil Consumption (Barrels)                    -0.029965
# World Share                                        -0.030067
# Yearly Gallons Per Capita                           0.057293
# Price Per Gallon (USD)                              1.000000
# Price Per Liter (USD)                               0.999997
# Price Per Liter (PKR)                               1.000000
# GDP Per Capita ( USD )                              0.182356
# Gallons GDP Per Capita Can Buy                     -0.127351
# xTimes Yearly Gallons Per Capita Buy               -0.144467
# Oil usage per person                               -0.090789
#
#                                       Price Per Liter (USD)  \
# S#                                                 0.121623
# Daily Oil Consumption (Barrels)                   -0.030106
# World Share                                       -0.030217
# Yearly Gallons Per Capita                          0.057471
# Price Per Gallon (USD)                             0.999997
# Price Per Liter (USD)                              1.000000
# Price Per Liter (PKR)                              0.999997
# GDP Per Capita ( USD )                             0.182663
# Gallons GDP Per Capita Can Buy                    -0.127428
# xTimes Yearly Gallons Per Capita Buy              -0.144567
# Oil usage per person                              -0.091177
#
#                                       Price Per Liter (PKR)  \
# S#                                                 0.121741
# Daily Oil Consumption (Barrels)                   -0.029938
# World Share                                       -0.030040
# Yearly Gallons Per Capita                          0.057368
# Price Per Gallon (USD)                             1.000000
# Price Per Liter (USD)                              0.999997
# Price Per Liter (PKR)                              1.000000
# GDP Per Capita ( USD )                             0.182437
# Gallons GDP Per Capita Can Buy                    -0.127275
# xTimes Yearly Gallons Per Capita Buy              -0.144409
# Oil usage per person                              -0.090822
#
#                                       GDP Per Capita ( USD )  \
# S#                                                 -0.269779
# Daily Oil Consumption (Barrels)                     0.190066
# World Share                                         0.181224
# Yearly Gallons Per Capita                           0.622038
# Price Per Gallon (USD)                              0.182356
# Price Per Liter (USD)                               0.182663
# Price Per Liter (PKR)                               0.182437
# GDP Per Capita ( USD )                              1.000000
# Gallons GDP Per Capita Can Buy                      0.188181
# xTimes Yearly Gallons Per Capita Buy                0.021875
# Oil usage per person                               -0.105524
#
#                                       Gallons GDP Per Capita Can Buy  \
# S#                                                         -0.160051
# Daily Oil Consumption (Barrels)                             0.051464
# World Share                                                 0.064107
# Yearly Gallons Per Capita                                   0.150975
# Price Per Gallon (USD)                                     -0.127351
# Price Per Liter (USD)                                      -0.127428
# Price Per Liter (PKR)                                      -0.127275
# GDP Per Capita ( USD )                                      0.188181
# Gallons GDP Per Capita Can Buy                              1.000000
# xTimes Yearly Gallons Per Capita Buy                        0.966148
# Oil usage per person                                       -0.017731
#
#                                       xTimes Yearly Gallons Per Capita Buy  \
# S#                                                               -0.109388
# Daily Oil Consumption (Barrels)                                   0.007332
# World Share                                                       0.022268
# Yearly Gallons Per Capita                                        -0.025534
# Price Per Gallon (USD)                                           -0.144467
# Price Per Liter (USD)                                            -0.144567
# Price Per Liter (PKR)                                            -0.144409
# GDP Per Capita ( USD )                                            0.021875
# Gallons GDP Per Capita Can Buy                                    0.966148
# xTimes Yearly Gallons Per Capita Buy                              1.000000
# Oil usage per person                                             -0.002056
#
#                                       Oil usage per person
# S#                                               -0.361556
# Daily Oil Consumption (Barrels)                   0.487674
# World Share                                       0.504923
# Yearly Gallons Per Capita                        -0.081313
# Price Per Gallon (USD)                           -0.090789
# Price Per Liter (USD)                            -0.091177
# Price Per Liter (PKR)                            -0.090822
# GDP Per Capita ( USD )                           -0.105524
# Gallons GDP Per Capita Can Buy                   -0.017731
# xTimes Yearly Gallons Per Capita Buy             -0.002056
# Oil usage per person                              1.000000

# %%
sns.pairplot(df, hue="World Share", palette="husl")

# %%
plt.figure(figsize=(20,10))
sns.heatmap(df.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### **Results**:
#
# 1. Since the data has no prior history that's why we can't consider 1.0 as an accurate positive correlation. It's flawed.
# 2. Correlations such as "0.97" are also suspicious but they might be usefeul if further data is collected.
# 3. Correlations "0.49, 0.50, 0.62" are interesting and should be kept a close eye on to.
